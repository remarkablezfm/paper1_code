# %% [markdown]
# # WOD-E2E segment inspection (step-by-step)
#
# 帮助快速验证 `seg_index_val_enriched.csv` 读取和 `SegmentRecord` 聚合逻辑。

# %%
from pathlib import Path
import pickle
import tensorflow as tf
from typing import List, Optional

from wod_e2e_exporter.io_reader import read_seg_index_enriched
from wod_e2e_exporter.utils import win_to_wsl_path

def _sanitize_name(s: str) -> str:
    return str(s).replace("/", "_").replace("\\", "_")

def cache_segments_full(
    seg_index_csv: str,
    out_root: str = r"D:\Datasets\WOD_E2E_Camera_v1\val_cache",
    seg_ids: Optional[List[str]] = None,
    max_segments: Optional[int] = None,
    skip_existing: bool = True,
    log_every: int = 1,
) -> list[Path]:
    out_root = Path(win_to_wsl_path(out_root))
    out_root.mkdir(parents=True, exist_ok=True)

    idx = read_seg_index_enriched(seg_index_csv)
    seg_id_list = seg_ids if seg_ids is not None else list(idx.keys())
    if max_segments is not None:
        seg_id_list = seg_id_list[:max_segments]

    total = len(seg_id_list)
    done = 0
    saved = []

    for seg_id in seg_id_list:
        rows = idx[seg_id]
        rows_sorted = sorted(
            rows,
            key=lambda r: (r.get("frame_id") if r.get("frame_id") is not None else 1e9, r.get("record_idx", 0)),
        )

        scenario_cluster = rows_sorted[0].get("scenario_cluster", "UNKNOWN")
        fname = f"{_sanitize_name(scenario_cluster)}_{_sanitize_name(seg_id)}.pkl"
        out_path = out_root / fname

        if skip_existing and out_path.exists():
            saved.append(out_path)
            done += 1
            if log_every and done % log_every == 0:
                print(f"[cache] total={total}, done={done}, remaining={total - done}")
            continue

        # group by tfrecord file
        by_file = {}
        for r in rows_sorted:
            by_file.setdefault(r["tfrecord_file"], set()).add(int(r["record_idx"]))

        e2e_bytes_by_key = {}
        for tfp, needed in by_file.items():
            ds = tf.data.TFRecordDataset(tfp, compression_type="")
            found = 0
            for i, rec in enumerate(ds):
                if i in needed:
                    e2e_bytes_by_key[(tfp, i)] = bytes(rec.numpy())
                    found += 1
                    if found == len(needed):
                        break

        # assemble in order
        missing = [
            r for r in rows_sorted
            if (r["tfrecord_file"], int(r["record_idx"])) not in e2e_bytes_by_key
        ]
        if missing:
            raise RuntimeError(f"missing records for seg_id={seg_id}: {len(missing)}")

        e2e_bytes_list = [
            e2e_bytes_by_key[(r["tfrecord_file"], int(r["record_idx"]))]
            for r in rows_sorted
        ]

        cache_obj = {
            "seg_id": seg_id,
            "scenario_cluster": scenario_cluster,
            "rows": rows_sorted,
            "frame_ids": [r.get("frame_id") for r in rows_sorted],
            "e2e_bytes": e2e_bytes_list,
        }

        with out_path.open("wb") as f:
            pickle.dump(cache_obj, f, protocol=pickle.HIGHEST_PROTOCOL)

        saved.append(out_path)
        done += 1
        if log_every and done % log_every == 0:
            print(f"[cache] total={total}, done={done}, remaining={total - done}")

    return saved
# Out:
# 2026-01-22 17:40:56.236350: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-22 17:40:56.237561: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-22 17:40:56.258039: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-22 17:40:56.259249: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-22 17:40:56.759720: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# # 只缓存一个 seg
# saved = cache_segments_full("seg_index_val_enriched.csv", seg_ids=["801a330a4f575841d82bd5200e2c4fb2"])
# print(saved)

# 或缓存前 N 个
# saved = cache_segments_full("seg_index_val_enriched.csv", max_segments=10)

# # 全量缓存
# saved = cache_segments_full("seg_index_val_enriched.csv")
# print("cached segments:", len(saved))

saved = cache_segments_full(
    "seg_index_val_enriched.csv",
    skip_existing=True,
)
# Out:
# [cache] total=479, done=1, remaining=478
# [cache] total=479, done=2, remaining=477
# [cache] total=479, done=3, remaining=476
# [cache] total=479, done=4, remaining=475
# [cache] total=479, done=5, remaining=474
# [cache] total=479, done=6, remaining=473
# [cache] total=479, done=7, remaining=472
# [cache] total=479, done=8, remaining=471
# [cache] total=479, done=9, remaining=470
# [cache] total=479, done=10, remaining=469
# [cache] total=479, done=11, remaining=468
# [cache] total=479, done=12, remaining=467
# [cache] total=479, done=13, remaining=466
# [cache] total=479, done=14, remaining=465
# [cache] total=479, done=15, remaining=464
# [cache] total=479, done=16, remaining=463
# [cache] total=479, done=17, remaining=462
# [cache] total=479, done=18, remaining=461
# [cache] total=479, done=19, remaining=460
# [cache] total=479, done=20, remaining=459
# [cache] total=479, done=21, remaining=458
# [cache] total=479, done=22, remaining=457
# [cache] total=479, done=23, remaining=456
# [cache] total=479, done=24, remaining=455
# [cache] total=479, done=25, remaining=454
# [cache] total=479, done=26, remaining=453
# [cache] total=479, done=27, remaining=452
# [cache] total=479, done=28, remaining=451
# [cache] total=479, done=29, remaining=450
# [cache] total=479, done=30, remaining=449
# [cache] total=479, done=31, remaining=448
# [cache] total=479, done=32, remaining=447
# [cache] total=479, done=33, remaining=446
# [cache] total=479, done=34, remaining=445
# [cache] total=479, done=35, remaining=444
# [cache] total=479, done=36, remaining=443
# [cache] total=479, done=37, remaining=442
# [cache] total=479, done=38, remaining=441
# [cache] total=479, done=39, remaining=440
# [cache] total=479, done=40, remaining=439
# [cache] total=479, done=41, remaining=438
# [cache] total=479, done=42, remaining=437
# [cache] total=479, done=43, remaining=436
# [cache] total=479, done=44, remaining=435
# [cache] total=479, done=45, remaining=434
# [cache] total=479, done=46, remaining=433
# [cache] total=479, done=47, remaining=432
# [cache] total=479, done=48, remaining=431
# [cache] total=479, done=49, remaining=430
# [cache] total=479, done=50, remaining=429
# [cache] total=479, done=51, remaining=428
# [cache] total=479, done=52, remaining=427
# [cache] total=479, done=53, remaining=426
# [cache] total=479, done=54, remaining=425
# [cache] total=479, done=55, remaining=424
# [cache] total=479, done=56, remaining=423
# [cache] total=479, done=57, remaining=422
# [cache] total=479, done=58, remaining=421
# [cache] total=479, done=59, remaining=420
# [cache] total=479, done=60, remaining=419
# [cache] total=479, done=61, remaining=418
# [cache] total=479, done=62, remaining=417
# [cache] total=479, done=63, remaining=416
# [cache] total=479, done=64, remaining=415
# [cache] total=479, done=65, remaining=414
# [cache] total=479, done=66, remaining=413
# [cache] total=479, done=67, remaining=412
# [cache] total=479, done=68, remaining=411
# [cache] total=479, done=69, remaining=410
# [cache] total=479, done=70, remaining=409
# [cache] total=479, done=71, remaining=408
# [cache] total=479, done=72, remaining=407
# [cache] total=479, done=73, remaining=406
# [cache] total=479, done=74, remaining=405
# [cache] total=479, done=75, remaining=404
# [cache] total=479, done=76, remaining=403
# [cache] total=479, done=77, remaining=402
# [cache] total=479, done=78, remaining=401
# [cache] total=479, done=79, remaining=400
# [cache] total=479, done=80, remaining=399
# [cache] total=479, done=81, remaining=398
# [cache] total=479, done=82, remaining=397
# [cache] total=479, done=83, remaining=396
# [cache] total=479, done=84, remaining=395
# [cache] total=479, done=85, remaining=394
# [cache] total=479, done=86, remaining=393
# [cache] total=479, done=87, remaining=392
# [cache] total=479, done=88, remaining=391
# [cache] total=479, done=89, remaining=390
# [cache] total=479, done=90, remaining=389
# [cache] total=479, done=91, remaining=388
# [cache] total=479, done=92, remaining=387
# [cache] total=479, done=93, remaining=386
# [cache] total=479, done=94, remaining=385
# [cache] total=479, done=95, remaining=384
# [cache] total=479, done=96, remaining=383
# [cache] total=479, done=97, remaining=382
# [cache] total=479, done=98, remaining=381
# [cache] total=479, done=99, remaining=380
# [cache] total=479, done=100, remaining=379
# [cache] total=479, done=101, remaining=378
# [cache] total=479, done=102, remaining=377
# [cache] total=479, done=103, remaining=376
# [cache] total=479, done=104, remaining=375
# [cache] total=479, done=105, remaining=374
# [cache] total=479, done=106, remaining=373
# [cache] total=479, done=107, remaining=372
# [cache] total=479, done=108, remaining=371
# [cache] total=479, done=109, remaining=370
# [cache] total=479, done=110, remaining=369
# [cache] total=479, done=111, remaining=368
# [cache] total=479, done=112, remaining=367
# [cache] total=479, done=113, remaining=366
# [cache] total=479, done=114, remaining=365
# [cache] total=479, done=115, remaining=364
# [cache] total=479, done=116, remaining=363
# [cache] total=479, done=117, remaining=362
# [cache] total=479, done=118, remaining=361
# [cache] total=479, done=119, remaining=360
# [cache] total=479, done=120, remaining=359
# [cache] total=479, done=121, remaining=358
# [cache] total=479, done=122, remaining=357
# [cache] total=479, done=123, remaining=356
# [cache] total=479, done=124, remaining=355
# [cache] total=479, done=125, remaining=354
# [cache] total=479, done=126, remaining=353
# [cache] total=479, done=127, remaining=352
# [cache] total=479, done=128, remaining=351
# [cache] total=479, done=129, remaining=350
# [cache] total=479, done=130, remaining=349
# [cache] total=479, done=131, remaining=348
# [cache] total=479, done=132, remaining=347
# [cache] total=479, done=133, remaining=346
# [cache] total=479, done=134, remaining=345
# [cache] total=479, done=135, remaining=344
# [cache] total=479, done=136, remaining=343
# [cache] total=479, done=137, remaining=342
# [cache] total=479, done=138, remaining=341
# [cache] total=479, done=139, remaining=340
# [cache] total=479, done=140, remaining=339
# [cache] total=479, done=141, remaining=338
# [cache] total=479, done=142, remaining=337
# [cache] total=479, done=143, remaining=336
# [cache] total=479, done=144, remaining=335
# [cache] total=479, done=145, remaining=334
# [cache] total=479, done=146, remaining=333
# [cache] total=479, done=147, remaining=332
# [cache] total=479, done=148, remaining=331
# [cache] total=479, done=149, remaining=330
# [cache] total=479, done=150, remaining=329
# [cache] total=479, done=151, remaining=328
# [cache] total=479, done=152, remaining=327
# [cache] total=479, done=153, remaining=326
# [cache] total=479, done=154, remaining=325
# [cache] total=479, done=155, remaining=324
# [cache] total=479, done=156, remaining=323
# [cache] total=479, done=157, remaining=322
# [cache] total=479, done=158, remaining=321
# [cache] total=479, done=159, remaining=320
# [cache] total=479, done=160, remaining=319
# [cache] total=479, done=161, remaining=318
# [cache] total=479, done=162, remaining=317
# [cache] total=479, done=163, remaining=316
# [cache] total=479, done=164, remaining=315
# [cache] total=479, done=165, remaining=314
# [cache] total=479, done=166, remaining=313
# [cache] total=479, done=167, remaining=312
# [cache] total=479, done=168, remaining=311
# [cache] total=479, done=169, remaining=310
# [cache] total=479, done=170, remaining=309
# [cache] total=479, done=171, remaining=308
# [cache] total=479, done=172, remaining=307
# [cache] total=479, done=173, remaining=306
# [cache] total=479, done=174, remaining=305
# [cache] total=479, done=175, remaining=304
# [cache] total=479, done=176, remaining=303
# [cache] total=479, done=177, remaining=302
# [cache] total=479, done=178, remaining=301
# [cache] total=479, done=179, remaining=300
# [cache] total=479, done=180, remaining=299
# [cache] total=479, done=181, remaining=298
# [cache] total=479, done=182, remaining=297
# [cache] total=479, done=183, remaining=296
# [cache] total=479, done=184, remaining=295
# [cache] total=479, done=185, remaining=294
# [cache] total=479, done=186, remaining=293
# [cache] total=479, done=187, remaining=292
# [cache] total=479, done=188, remaining=291
# [cache] total=479, done=189, remaining=290
# 2026-01-22 17:41:03.212502: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-22 17:41:03.212744: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# [cache] total=479, done=190, remaining=289
# [cache] total=479, done=191, remaining=288
# [cache] total=479, done=192, remaining=287
# [cache] total=479, done=193, remaining=286
# [cache] total=479, done=194, remaining=285
# [cache] total=479, done=195, remaining=284
# [cache] total=479, done=196, remaining=283
# [cache] total=479, done=197, remaining=282
# [cache] total=479, done=198, remaining=281
# [cache] total=479, done=199, remaining=280
# [cache] total=479, done=200, remaining=279
# [cache] total=479, done=201, remaining=278
# [cache] total=479, done=202, remaining=277
# [cache] total=479, done=203, remaining=276
# [cache] total=479, done=204, remaining=275
# [cache] total=479, done=205, remaining=274
# [cache] total=479, done=206, remaining=273
# [cache] total=479, done=207, remaining=272
# [cache] total=479, done=208, remaining=271
# [cache] total=479, done=209, remaining=270
# [cache] total=479, done=210, remaining=269
# [cache] total=479, done=211, remaining=268
# [cache] total=479, done=212, remaining=267
# [cache] total=479, done=213, remaining=266
# [cache] total=479, done=214, remaining=265
# [cache] total=479, done=215, remaining=264
# [cache] total=479, done=216, remaining=263
# [cache] total=479, done=217, remaining=262
# [cache] total=479, done=218, remaining=261
# [cache] total=479, done=219, remaining=260
# [cache] total=479, done=220, remaining=259
# [cache] total=479, done=221, remaining=258
# [cache] total=479, done=222, remaining=257
# [cache] total=479, done=223, remaining=256
# [cache] total=479, done=224, remaining=255
# [cache] total=479, done=225, remaining=254
# [cache] total=479, done=226, remaining=253
# [cache] total=479, done=227, remaining=252
# [cache] total=479, done=228, remaining=251
# [cache] total=479, done=229, remaining=250
# [cache] total=479, done=230, remaining=249
# [cache] total=479, done=231, remaining=248
# [cache] total=479, done=232, remaining=247
# [cache] total=479, done=233, remaining=246
# [cache] total=479, done=234, remaining=245
# [cache] total=479, done=235, remaining=244
# [cache] total=479, done=236, remaining=243
# [cache] total=479, done=237, remaining=242
# [cache] total=479, done=238, remaining=241
# [cache] total=479, done=239, remaining=240
# [cache] total=479, done=240, remaining=239
# [cache] total=479, done=241, remaining=238
# [cache] total=479, done=242, remaining=237
# [cache] total=479, done=243, remaining=236
# [cache] total=479, done=244, remaining=235
# [cache] total=479, done=245, remaining=234
# [cache] total=479, done=246, remaining=233
# [cache] total=479, done=247, remaining=232
# [cache] total=479, done=248, remaining=231
# [cache] total=479, done=249, remaining=230
# [cache] total=479, done=250, remaining=229
# [cache] total=479, done=251, remaining=228
# [cache] total=479, done=252, remaining=227
# [cache] total=479, done=253, remaining=226
# [cache] total=479, done=254, remaining=225
# [cache] total=479, done=255, remaining=224
# [cache] total=479, done=256, remaining=223
# [cache] total=479, done=257, remaining=222
# [cache] total=479, done=258, remaining=221
# [cache] total=479, done=259, remaining=220
# [cache] total=479, done=260, remaining=219
# [cache] total=479, done=261, remaining=218
# [cache] total=479, done=262, remaining=217
# [cache] total=479, done=263, remaining=216
# [cache] total=479, done=264, remaining=215
# [cache] total=479, done=265, remaining=214
# [cache] total=479, done=266, remaining=213
# [cache] total=479, done=267, remaining=212
# [cache] total=479, done=268, remaining=211
# [cache] total=479, done=269, remaining=210
# [cache] total=479, done=270, remaining=209
# [cache] total=479, done=271, remaining=208
# [cache] total=479, done=272, remaining=207
# [cache] total=479, done=273, remaining=206
# [cache] total=479, done=274, remaining=205
# [cache] total=479, done=275, remaining=204
# [cache] total=479, done=276, remaining=203
# [cache] total=479, done=277, remaining=202
# [cache] total=479, done=278, remaining=201
# [cache] total=479, done=279, remaining=200
# [cache] total=479, done=280, remaining=199
# [cache] total=479, done=281, remaining=198
# [cache] total=479, done=282, remaining=197
# [cache] total=479, done=283, remaining=196
# [cache] total=479, done=284, remaining=195
# [cache] total=479, done=285, remaining=194
# [cache] total=479, done=286, remaining=193
# [cache] total=479, done=287, remaining=192
# [cache] total=479, done=288, remaining=191
# [cache] total=479, done=289, remaining=190
# [cache] total=479, done=290, remaining=189
# [cache] total=479, done=291, remaining=188
# [cache] total=479, done=292, remaining=187
# [cache] total=479, done=293, remaining=186
# [cache] total=479, done=294, remaining=185
# [cache] total=479, done=295, remaining=184
# [cache] total=479, done=296, remaining=183
# [cache] total=479, done=297, remaining=182
# [cache] total=479, done=298, remaining=181
# [cache] total=479, done=299, remaining=180
# [cache] total=479, done=300, remaining=179
# [cache] total=479, done=301, remaining=178
# [cache] total=479, done=302, remaining=177
# [cache] total=479, done=303, remaining=176
# [cache] total=479, done=304, remaining=175
# [cache] total=479, done=305, remaining=174
# [cache] total=479, done=306, remaining=173
# [cache] total=479, done=307, remaining=172
# [cache] total=479, done=308, remaining=171
# [cache] total=479, done=309, remaining=170
# [cache] total=479, done=310, remaining=169
# [cache] total=479, done=311, remaining=168
# [cache] total=479, done=312, remaining=167
# [cache] total=479, done=313, remaining=166
# [cache] total=479, done=314, remaining=165
# [cache] total=479, done=315, remaining=164
# [cache] total=479, done=316, remaining=163
# [cache] total=479, done=317, remaining=162
# [cache] total=479, done=318, remaining=161
# [cache] total=479, done=319, remaining=160
# [cache] total=479, done=320, remaining=159
# [cache] total=479, done=321, remaining=158
# [cache] total=479, done=322, remaining=157
# [cache] total=479, done=323, remaining=156
# [cache] total=479, done=324, remaining=155
# [cache] total=479, done=325, remaining=154
# [cache] total=479, done=326, remaining=153
# [cache] total=479, done=327, remaining=152
# [cache] total=479, done=328, remaining=151
# [cache] total=479, done=329, remaining=150
# [cache] total=479, done=330, remaining=149
# [cache] total=479, done=331, remaining=148
# [cache] total=479, done=332, remaining=147
# [cache] total=479, done=333, remaining=146
# [cache] total=479, done=334, remaining=145
# [cache] total=479, done=335, remaining=144
# [cache] total=479, done=336, remaining=143
# [cache] total=479, done=337, remaining=142
# [cache] total=479, done=338, remaining=141
# [cache] total=479, done=339, remaining=140
# [cache] total=479, done=340, remaining=139
# [cache] total=479, done=341, remaining=138
# [cache] total=479, done=342, remaining=137
# [cache] total=479, done=343, remaining=136
# [cache] total=479, done=344, remaining=135
# [cache] total=479, done=345, remaining=134
# [cache] total=479, done=346, remaining=133
# [cache] total=479, done=347, remaining=132
# [cache] total=479, done=348, remaining=131
# [cache] total=479, done=349, remaining=130
# [cache] total=479, done=350, remaining=129
# [cache] total=479, done=351, remaining=128
# [cache] total=479, done=352, remaining=127
# [cache] total=479, done=353, remaining=126
# [cache] total=479, done=354, remaining=125
# [cache] total=479, done=355, remaining=124
# [cache] total=479, done=356, remaining=123
# [cache] total=479, done=357, remaining=122
# [cache] total=479, done=358, remaining=121
# [cache] total=479, done=359, remaining=120
# [cache] total=479, done=360, remaining=119
# [cache] total=479, done=361, remaining=118
# [cache] total=479, done=362, remaining=117
# [cache] total=479, done=363, remaining=116
# [cache] total=479, done=364, remaining=115
# [cache] total=479, done=365, remaining=114
# [cache] total=479, done=366, remaining=113
# [cache] total=479, done=367, remaining=112
# [cache] total=479, done=368, remaining=111
# [cache] total=479, done=369, remaining=110
# [cache] total=479, done=370, remaining=109
# [cache] total=479, done=371, remaining=108
# [cache] total=479, done=372, remaining=107
# [cache] total=479, done=373, remaining=106
# [cache] total=479, done=374, remaining=105
# [cache] total=479, done=375, remaining=104
# [cache] total=479, done=376, remaining=103
# [cache] total=479, done=377, remaining=102
# [cache] total=479, done=378, remaining=101
# [cache] total=479, done=379, remaining=100
# [cache] total=479, done=380, remaining=99
# [cache] total=479, done=381, remaining=98
# [cache] total=479, done=382, remaining=97
# [cache] total=479, done=383, remaining=96
# [cache] total=479, done=384, remaining=95
# [cache] total=479, done=385, remaining=94
# [cache] total=479, done=386, remaining=93
# [cache] total=479, done=387, remaining=92
# [cache] total=479, done=388, remaining=91
# [cache] total=479, done=389, remaining=90
# [cache] total=479, done=390, remaining=89
# [cache] total=479, done=391, remaining=88
# [cache] total=479, done=392, remaining=87
# [cache] total=479, done=393, remaining=86
# [cache] total=479, done=394, remaining=85
# [cache] total=479, done=395, remaining=84
# [cache] total=479, done=396, remaining=83
# [cache] total=479, done=397, remaining=82
# [cache] total=479, done=398, remaining=81
# [cache] total=479, done=399, remaining=80
# [cache] total=479, done=400, remaining=79
# [cache] total=479, done=401, remaining=78
# [cache] total=479, done=402, remaining=77
# [cache] total=479, done=403, remaining=76
# [cache] total=479, done=404, remaining=75
# [cache] total=479, done=405, remaining=74
# [cache] total=479, done=406, remaining=73
# [cache] total=479, done=407, remaining=72
# [cache] total=479, done=408, remaining=71
# [cache] total=479, done=409, remaining=70
# [cache] total=479, done=410, remaining=69
# [cache] total=479, done=411, remaining=68
# [cache] total=479, done=412, remaining=67
# [cache] total=479, done=413, remaining=66
# [cache] total=479, done=414, remaining=65
# [cache] total=479, done=415, remaining=64
# [cache] total=479, done=416, remaining=63
# [cache] total=479, done=417, remaining=62
# [cache] total=479, done=418, remaining=61
# [cache] total=479, done=419, remaining=60
# [cache] total=479, done=420, remaining=59
# [cache] total=479, done=421, remaining=58
# [cache] total=479, done=422, remaining=57
# [cache] total=479, done=423, remaining=56
# [cache] total=479, done=424, remaining=55
# [cache] total=479, done=425, remaining=54
# [cache] total=479, done=426, remaining=53
# [cache] total=479, done=427, remaining=52
# [cache] total=479, done=428, remaining=51
# [cache] total=479, done=429, remaining=50
# [cache] total=479, done=430, remaining=49
# [cache] total=479, done=431, remaining=48
# [cache] total=479, done=432, remaining=47
# [cache] total=479, done=433, remaining=46
# [cache] total=479, done=434, remaining=45
# [cache] total=479, done=435, remaining=44
# [cache] total=479, done=436, remaining=43
# [cache] total=479, done=437, remaining=42
# [cache] total=479, done=438, remaining=41
# [cache] total=479, done=439, remaining=40
# [cache] total=479, done=440, remaining=39
# [cache] total=479, done=441, remaining=38
# [cache] total=479, done=442, remaining=37
# [cache] total=479, done=443, remaining=36
# [cache] total=479, done=444, remaining=35
# [cache] total=479, done=445, remaining=34
# [cache] total=479, done=446, remaining=33
# [cache] total=479, done=447, remaining=32
# [cache] total=479, done=448, remaining=31
# [cache] total=479, done=449, remaining=30
# [cache] total=479, done=450, remaining=29
# [cache] total=479, done=451, remaining=28
# [cache] total=479, done=452, remaining=27
# [cache] total=479, done=453, remaining=26
# [cache] total=479, done=454, remaining=25
# [cache] total=479, done=455, remaining=24
# [cache] total=479, done=456, remaining=23
# [cache] total=479, done=457, remaining=22
# [cache] total=479, done=458, remaining=21
# [cache] total=479, done=459, remaining=20
# [cache] total=479, done=460, remaining=19
# [cache] total=479, done=461, remaining=18
# [cache] total=479, done=462, remaining=17
# [cache] total=479, done=463, remaining=16
# [cache] total=479, done=464, remaining=15
# [cache] total=479, done=465, remaining=14
# [cache] total=479, done=466, remaining=13
# [cache] total=479, done=467, remaining=12
# [cache] total=479, done=468, remaining=11
# [cache] total=479, done=469, remaining=10
# [cache] total=479, done=470, remaining=9
# [cache] total=479, done=471, remaining=8
# [cache] total=479, done=472, remaining=7
# [cache] total=479, done=473, remaining=6
# [cache] total=479, done=474, remaining=5
# [cache] total=479, done=475, remaining=4
# [cache] total=479, done=476, remaining=3
# [cache] total=479, done=477, remaining=2
# [cache] total=479, done=478, remaining=1
# [cache] total=479, done=479, remaining=0
